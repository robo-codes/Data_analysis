# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\solan\\Downloads\\car_data.csv")

# %%
plt.figure(figsize=[20,10])
sns.displot(data['Selling Price'])
plt.title("HAHAHAHAHA")
# Out:
# Text(0.5, 1.0, 'HAHAHAHAHA')

# %%
qMileage = data['Kilometers Driven'].quantile(0.99)
data = data[data['Kilometers Driven']<qMileage]
sns.displot(data['Kilometers Driven'])
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2169 entries, 0 to 2236
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              2169 non-null   object
#  1   Selling Price      2169 non-null   int64
#  2   Kilometers Driven  2169 non-null   int64
#  3   Year               2169 non-null   int64
#  4   Owner              2169 non-null   object
#  5   Fuel Type          2169 non-null   object
#  6   Transmission       2169 non-null   object
#  7   Insurance          2155 non-null   object
#  8   Car Condition      2169 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 169.5+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24388\3446664367.py in <module>
# ----> 1 data['Owner'].value_count().plot.pie()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'
